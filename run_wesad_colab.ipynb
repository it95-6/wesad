# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/wesad_repo
# !git clone https://github.com/it95-6/wesad.git /content/wesad_repo
# Out:
# Cloning into '/content/wesad_repo'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 20 (delta 2), reused 20 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 16.05 KiB | 16.05 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import os
import sys
from pathlib import Path
import torch

print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")

PROJECT_ROOT = Path("/content/drive/MyDrive/WESAD_project")
REPO_ROOT = Path("/content/wesad_repo")
DATA_ROOT = PROJECT_ROOT / "data"
OUTPUT_ROOT = PROJECT_ROOT / "outputs"

os.environ["WESAD_PROJECT_ROOT"] = str(PROJECT_ROOT)
os.environ["WESAD_REPO_ROOT"] = str(REPO_ROOT)
os.environ["WESAD_DATA_ROOT"] = str(DATA_ROOT)
os.environ["WESAD_OUTPUT_ROOT"] = str(OUTPUT_ROOT)
os.environ["WESAD_NPZ_PATH"] = str(DATA_ROOT / "wesad_windows.npz")
os.environ["WESAD_NUM_WORKERS"] = "2"
os.environ["WESAD_REQUIRE_CUDA"] = "1"
os.environ["WESAD_USE_AMP"] = "1"

print("npz exists:", Path(os.environ["WESAD_NPZ_PATH"]).exists())
# Out:
# CUDA available: True
# GPU: Tesla T4
# npz exists: True

# %%
# %cd /content/wesad_repo
# !pip install -q torch torchvision torchaudio scikit-learn seaborn matplotlib numpy pandas
# !python -m research.train_cnn
# Out:
# /content/wesad_repo
# Using device: cuda
# GPU: Tesla T4
# Loaded raw NPZ: X=(5770, 21000, 2), y=(5770,)
# Train: (2096, 2, 21000), (2096,)
# Val  : (300, 2, 21000), (300,)
# Test : (600, 2, 21000), (600,)
# [Epoch 01/20] train_loss=1.2832 train_acc=0.4008 train_f1=0.2930 val_loss=1.2706 val_acc=0.4133 val_f1=0.2797
# [Epoch 02/20] train_loss=1.2115 train_acc=0.4838 train_f1=0.3526 val_loss=1.1471 val_acc=0.5700 val_f1=0.4316
# [Epoch 03/20] train_loss=1.1642 train_acc=0.5215 train_f1=0.3922 val_loss=1.1935 val_acc=0.5333 val_f1=0.4001
# [Epoch 04/20] train_loss=1.1295 train_acc=0.5277 train_f1=0.3872 val_loss=1.0753 val_acc=0.5667 val_f1=0.4091
# [Epoch 05/20] train_loss=1.1172 train_acc=0.5401 train_f1=0.4188 val_loss=1.0267 val_acc=0.6267 val_f1=0.4785
# [Epoch 06/20] train_loss=1.0788 train_acc=0.5496 train_f1=0.4238 val_loss=1.1334 val_acc=0.5700 val_f1=0.4239
# [Epoch 07/20] train_loss=1.0640 train_acc=0.5530 train_f1=0.4341 val_loss=1.4877 val_acc=0.4833 val_f1=0.3487
# [Epoch 08/20] train_loss=1.1090 train_acc=0.5219 train_f1=0.4044 val_loss=1.0245 val_acc=0.6033 val_f1=0.4254
# [Epoch 09/20] train_loss=1.0573 train_acc=0.5687 train_f1=0.4387 val_loss=0.9700 val_acc=0.6200 val_f1=0.4662
# [Epoch 10/20] train_loss=1.0181 train_acc=0.5930 train_f1=0.4665 val_loss=1.0034 val_acc=0.5833 val_f1=0.4511
# [Epoch 11/20] train_loss=1.0420 train_acc=0.5787 train_f1=0.4587 val_loss=0.9385 val_acc=0.6200 val_f1=0.4859
# [Epoch 12/20] train_loss=1.0175 train_acc=0.5830 train_f1=0.4551 val_loss=0.9201 val_acc=0.6333 val_f1=0.5170
# [Epoch 13/20] train_loss=0.9911 train_acc=0.5959 train_f1=0.4724 val_loss=0.9114 val_acc=0.6367 val_f1=0.4779
# [Epoch 14/20] train_loss=1.0522 train_acc=0.5620 train_f1=0.4429 val_loss=0.9097 val_acc=0.6400 val_f1=0.5091
# [Epoch 15/20] train_loss=1.0201 train_acc=0.5835 train_f1=0.4601 val_loss=1.0428 val_acc=0.6000 val_f1=0.4313
# [Epoch 16/20] train_loss=1.0030 train_acc=0.5806 train_f1=0.4562 val_loss=0.8703 val_acc=0.6567 val_f1=0.5092
# [Epoch 17/20] train_loss=0.9949 train_acc=0.5849 train_f1=0.4617 val_loss=0.9131 val_acc=0.6467 val_f1=0.4994
# [Epoch 18/20] train_loss=0.9547 train_acc=0.6040 train_f1=0.4712 val_loss=0.8946 val_acc=0.6367 val_f1=0.5009
# [Epoch 19/20] train_loss=0.9463 train_acc=0.6088 train_f1=0.4881 val_loss=0.8411 val_acc=0.6867 val_f1=0.5418
# [Epoch 20/20] train_loss=0.9527 train_acc=0.6050 train_f1=0.4790 val_loss=0.9240 val_acc=0.6267 val_f1=0.4923
#
# === Test Metrics ===
# Accuracy : 0.6583
# Macro F1 : 0.5221
# Confusion matrix:
# [[211   3   0  21]
#  [ 23  98   0  13]
#  [ 49   8   0  17]
#  [ 61  10   0  86]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6134    0.8979    0.7288       235
#            1     0.8235    0.7313    0.7747       134
#            2     0.0000    0.0000    0.0000        74
#            3     0.6277    0.5478    0.5850       157
#
#     accuracy                         0.6583       600
#    macro avg     0.5162    0.5442    0.5221       600
# weighted avg     0.5884    0.6583    0.6116       600
#
# Best model saved to: /content/drive/MyDrive/WESAD_project/outputs/models/cnn1d_ecg_eda_best.pt

# %%
# !python -m research.evaluate_cnn
# Out:
# Using device: cuda
# GPU: Tesla T4
# === Evaluation ===
# Accuracy : 0.6583
# Macro F1 : 0.5221
# Confusion matrix:
# [[211   3   0  21]
#  [ 23  98   0  13]
#  [ 49   8   0  17]
#  [ 61  10   0  86]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6134    0.8979    0.7288       235
#            1     0.8235    0.7313    0.7747       134
#            2     0.0000    0.0000    0.0000        74
#            3     0.6277    0.5478    0.5850       157
#
#     accuracy                         0.6583       600
#    macro avg     0.5162    0.5442    0.5221       600
# weighted avg     0.5884    0.6583    0.6116       600
#
# Figure(600x500)
# Saved figure to: /content/drive/MyDrive/WESAD_project/outputs/figures/cnn1d_ecg_eda_confusion_matrix.png
